# %% [markdown]
# # 베스트 플레이어 평가
#
# 베스트 플레이어 평가를 수행한다.
#
# 베스트 플레이어를 랜덤, 알파베타법, 몬테카를로 트리 탐색과 대전시켜 승률을 표시하도록 처리해 베스트 플레이어 교대 시 실행한다.
#
# 베스트 플레이어를 평가하는 과정이 학습 사이클에 필수적이지는 않으나, 학습을 통해 모델이 실제로 강해졌는지를 확인할 수 있다. 이번에는 평가 목적의 코드를 구현하는 것뿐이며, 각 코드의 동작은 학습 전의 모델에서 확인할 수 있다.
#
# * 파라미터 준비
#
# 파라미터 준비를 수행한다. 'EP_GAME_COUNT'는 승률을 계산하기 위한 게임의 횟수다.
#
# * 선 수를 둔 플레이어의 포인트
#
# * 게임 1회 실행
#
# * 임의의 알고리즘을 활용한 평가
#
# 'evaluate_algorithm_of(label, next_actions)'는 인수에 전달한 임의의 알고리즘을 평가한다. 'label'이 print()로 출력하는 알고리즘명, 'next_actions'는 알고리즘 함수다.
#
# * 베스트 플레이어 평가
#
# 'evaluate_best_player()'는 베스트 플레이어를 평가한다.

# %%
# evaluate_network.py 업로드
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5490e86b-e802-4f85-ac6d-54ab568afdc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5490e86b-e802-4f85-ac6d-54ab568afdc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dual_network.py to dual_network.py
# Saving evaluate_best_player.py to evaluate_best_player.py
# Saving evaluate_network.py to evaluate_network.py
# Saving game.py to game.py
# Saving pv_mcts.py to pv_mcts.py
# Saving self_play.py to self_play.py
# Saving train_network.py to train_network.py

# %%
! dir
# Out:
# dual_network.py		 evaluate_network.py  pv_mcts.py   self_play.py
# evaluate_best_player.py  game.py	      sample_data  train_network.py

# %%
# !python game.py
# Out:
# ---
# --o
# ---
#
# ---
# x-o
# ---
#
# ---
# x-o
# --o
#
# ---
# x-o
# x-o
#
# o--
# x-o
# x-o
#
# o--
# xxo
# x-o
#
# o-o
# xxo
# x-o

# %%
# !python dual_network.py
# Out:
# 2021-04-21 14:32:27.552109: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-21 14:32:29.715361: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-21 14:32:29.716540: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-21 14:32:29.790162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-21 14:32:29.790978: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# ...

# %%
# !python pv_mcts.py
# Out:
# 2021-04-21 14:32:36.834091: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-21 14:32:39.067054: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-21 14:32:39.068031: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-21 14:32:39.092019: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-21 14:32:39.092961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# ...

# %%
# !python self_play.py
# Out:
# 2021-04-21 14:33:18.220814: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-21 14:33:20.441363: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-21 14:33:20.442338: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-21 14:33:20.462784: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-21 14:33:20.463604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# ...

# %%
# !python train_network.py
# Out:
# 2021-04-21 15:31:20.689672: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-21 15:31:22.856101: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-21 15:31:22.857134: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-21 15:31:22.879983: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-21 15:31:22.880783: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# ...

# %%
# !python evaluate_network.py
# Out:
# 2021-04-21 15:34:53.692742: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-21 15:34:55.774597: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-21 15:34:55.775564: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-21 15:34:55.796271: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-21 15:34:55.797078: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# ...

# %%
# !python evaluate_best_player.py
# Out:
# 2021-04-21 15:36:05.080710: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-21 15:36:07.150748: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-21 15:36:07.151752: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-21 15:36:07.171886: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-21 15:36:07.172652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# ...
